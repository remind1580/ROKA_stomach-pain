# %%
# multiprocessing 관련 오류 발생 시
# export OBJC_DISABLE_INITIALIZE_FORK_SAFETY=YES

import pandas as pd
from tqdm import tqdm
from pandarallel import pandarallel
from py_hanspell.hanspell import spell_checker

import warnings
warnings.filterwarnings("ignore")

tqdm.pandas()
pandarallel.initialize(progress_bar=True)


def check_ko_spell(x):
    try:
        if str(type(x['main_symtom_1'])) == "<class 'str'>":
            x['main_symtom_1'] = spell_checker.check(x['main_symtom_1']).as_dict()['checked']
        if str(type(x['main_symtom_2'])) == "<class 'str'>":
            x['main_symtom_1'] = spell_checker.check(x['main_symtom_1']).as_dict()['checked']
    except:
        pass

    return x


# df = pd.read_excel("data/prepared_dataset.xlsx", engine="openpyxl")
# df = df.parallel_apply(check_ko_spell, axis=1)
# df.to_excel("data/prepared_dataset.xlsx", index=False)
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
df = pd.read_excel("data/prepared_dataset_negative-returning-home-only.xlsx", engine="openpyxl")
# df = df.parallel_apply(check_ko_spell, axis=1)
# df.to_excel("data/prepared_dataset_negative-returning-home-only.xlsx", index=False)

# %%
df
# Out:
#       center  age  gender  height  weight        BMI  BMI_group  is_operation  \
# 0     국군수도병원   23       0   173.0    61.0  20.381570          1             1
# 1     국군수도병원   20       1   171.0    69.0  23.597004          1             1
# 2     국군수도병원   20       1   169.0    64.0  22.408179          1             1
# 3     국군수도병원   21       1   166.0    65.0  23.588329          1             1
# 4     국군수도병원   32       1   185.0    84.0  24.543462          1             1
# ...      ...  ...     ...     ...     ...        ...        ...           ...
# 3526  해군포항병원   19       1   175.0    82.0  26.775510          2             0
# 3527  해군포항병원   22       1   181.0    76.0  23.198315          1             1
# 3528  해군포항병원   24       1   174.0    68.0  22.460034          1             1
# 3529  해군포항병원   19       1   180.0    64.0  19.753086          1             1
# 3530  해군포항병원   20       1   177.0    80.0  25.535446          2             1
#
# ...
